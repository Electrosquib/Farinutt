# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
df = pd.read_csv("HONEYCUTT_analysis_results.csv", index_col="Filename")

# %%
df
# Out:
#                            Word Count  COCA_spoken_Range_AW  \
# Filename
# EE_KOR_SMK0_B1_1_EDIT.txt        2048              0.525037
# EE_IDN_SMK0_A2_0_EDIT.txt        2137              0.595491
# EE_CHN_SMK0_B2_0_EDIT.txt        2487              0.563215
# EE_CHN_PTJ0_B1_2_EDIT.txt        2288              0.600249
# EE_JPN_PTJ0_B1_1_EDIT.txt        2305              0.637888
# EE_IDN_PTJ0_B2_0_EDIT.txt         714              0.584275
# EE_IDN_SMK0_B1_2_EDIT.txt        2152              0.583788
# EE_CHN_PTJ0_A2_0_EDIT.txt        2243              0.594914
# EE_CHN_PTJ0_B2_0_EDIT.txt        2550              0.565709
# EE_CHN_SMK0_B1_2_EDIT.txt        2287              0.570475
# EE_JPN_SMK0_B1_1_EDIT.txt        2198              0.595697
# EE_KOR_PTJ0_B1_1_EDIT.txt        2237              0.586682
# EE_IDN_PTJ0_A2_0_EDIT.txt        2180              0.577787
# EE_CHN_SMK0_A2_0_EDIT.txt        2280              0.600232
# ...
